# %%
import pandas as pd


dale = pd.read_csv("tweets.csv")
peggy = pd.read_csv("tweets_public.csv")
hank = pd.read_csv("ExtractedTweets.csv")

# %%
hank.columns
# Out:
# Index(['Party', 'Handle', 'Tweet'], dtype='object')

# %%
hank2 = hank[hank.Party == "Republican"]
bobby = hank[hank.Party == "Democrat"]

# %%
hank2
# Out:
#             Party          Handle  \
# 42068  Republican  RepRalphNorman
# 42069  Republican  RepRalphNorman
# 42070  Republican  RepRalphNorman
# 42071  Republican  RepRalphNorman
# 42072  Republican  RepRalphNorman
# 42073  Republican  RepRalphNorman
# 42074  Republican  RepRalphNorman
# 42075  Republican  RepRalphNorman
# 42076  Republican  RepRalphNorman
# 42077  Republican  RepRalphNorman
# 42078  Republican  RepRalphNorman
# 42079  Republican  RepRalphNorman
# 42080  Republican  RepRalphNorman
# 42081  Republican  RepRalphNorman
# 42082  Republican  RepRalphNorman
# 42083  Republican  RepRalphNorman
# 42084  Republican  RepRalphNorman
# 42085  Republican  RepRalphNorman
# 42086  Republican  RepRalphNorman
# 42087  Republican  RepRalphNorman
# 42088  Republican  RepRalphNorman
# 42089  Republican  RepRalphNorman
# 42090  Republican  RepRalphNorman
# 42091  Republican  RepRalphNorman
# 42092  Republican  RepRalphNorman
# 42093  Republican  RepRalphNorman
# ...

# %%
bobby = bobby[["Tweet"]]

# %%
bobby["Character"] = "bobby"
bobby["Quote"] = bobby["Tweet"]
# Out:
# /home/manny/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
bobby= bobby[["Character", "Quote"]]

# %%
bobby
# Out:
#       Character                                              Quote
# 0         bobby  Today, Senate Dems vote to #SaveTheInternet. P...
# 1         bobby  RT @WinterHavenSun: Winter Haven resident / Al...
# 2         bobby  RT @NBCLatino: .@RepDarrenSoto noted that Hurr...
# 3         bobby  RT @NALCABPolicy: Meeting with @RepDarrenSoto ...
# 4         bobby  RT @Vegalteno: Hurricane season starts on June...
# 5         bobby  RT @EmgageActionFL: Thank you to all who came ...
# 6         bobby  Hurricane Maria left approx $90 billion in dam...
# 7         bobby  RT @Tharryry: I am delighted that @RepDarrenSo...
# 8         bobby  RT @HispanicCaucus: Trump's anti-immigrant pol...
# 9         bobby  RT @RepStephMurphy: Great joining @WeAreUnidos...
# 10        bobby  RT @AllSaints_FL: Zhihan (John)'s art received...
# 11        bobby  .@realDonaldTrump official policy to separate ...
# 12        bobby  Thank you to my mom Jean and all the mothers a...
# ...

# %%
bobby.to_csv("bobby.csv", index=False)
